# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn import metrics

# %%
Dataset = pd.read_csv(r"C:\Users\HP\Downloads\diabetes.csv")
Dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Dataset.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
Dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Dataset.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
Datasetnew = Dataset[['Glucose','BloodPressure','Age','Outcome']]
Datasetnew
# Out:
#      Glucose  BloodPressure  Age  Outcome
# 0        148             72   50        1
# 1         85             66   31        0
# 2        183             64   32        1
# 3         89             66   21        0
# 4        137             40   33        1
# ..       ...            ...  ...      ...
# 763      101             76   63        0
# 764      122             70   27        0
# 765      121             72   30        0
# 766      126             60   47        1
# 767       93             70   23        0
#
# [768 rows x 4 columns]

# %%
sb.pairplot(Datasetnew,height = 3)

# %%
sb.jointplot(Datasetnew.Glucose,Datasetnew.BloodPressure)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = [10,10])
plt.xlabel('Age')
plt.ylabel('BloodPressure')
plt.scatter(x = 'Age',y = 'BloodPressure',edgecolors = 'black',color = 'orange',data = Datasetnew)
plt.show()

# %%
plt.figure(figsize = [10,10])
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.scatter(x = 'Age',y = 'Glucose',edgecolors = 'black',color = 'red',data = Datasetnew)
plt.show()

# %%
plt.figure(figsize = [10,10])
plt.xlabel('BloodPressure')
plt.ylabel('Glucose')
plt.scatter(x = 'BloodPressure',y = 'Glucose',edgecolors = 'black',color = 'yellow',data = Datasetnew)
plt.show()

# %%
A = Datasetnew[Datasetnew.Outcome == 1]

B = Datasetnew[Datasetnew.Outcome == 0]

# %%
plt.scatter(A.Glucose,A.BloodPressure,c ="black",linewidths = 2,marker ="s",edgecolor ="green",label = "1",s = 250)
plt.scatter(B.Glucose,B.BloodPressure, c ="red",linewidths = 1,marker ="s",edgecolor ="Black",label = "0",s = 130)
plt.xlabel("GLUCOSE")
plt.ylabel("BLOODPRESSURE")
plt.title('GLUCOSE VS BLOODPRESSURE')
plt.legend()
plt.show()

# %%
plt.scatter(A.Age,A.BloodPressure,c ="magenta", 
            linewidths = 2, 
            marker ="o", 
            edgecolor ="cyan",
            label = "1",
            s = 250)
plt.scatter(B.Age,B.BloodPressure, c ="red",
            linewidths = 1,
            marker ="o", 
            edgecolor ="Black",
            label = "0",
            s = 150)
plt.xlabel("AGE")
plt.ylabel("BLOODPRESURE")
plt.title('Age vs BloodPressure')
plt.legend()
plt.show()

# %%
plt.scatter(A.Age,A.Glucose,c ="black", 
            linewidths = 1, 
            marker ="o", 
            edgecolor ="cyan",
            label = "1",
            s = 250)
plt.scatter(B.Age,B.Glucose, c ="red",
            linewidths = 1,
            marker ="o", 
            edgecolor ="Black",
            label = "0",
            s = 170)
plt.xlabel("AGE")
plt.ylabel("GLUCOSE")
plt.title('Age vs Glucose')
plt.legend()
plt.show()

# %%
sb.boxplot(Dataset['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
x = Dataset.iloc[:,:-1]
y = Dataset.iloc[:,-1]

# %%
x_train, x_test, y_train ,y_test = train_test_split(x,y, random_state=0,test_size = 0.2)

# %%
print('using linear regression algorithm')
model_LR = LinearRegression()

model_LR.fit(x_train,y_train)

LR_score_train = model_LR.score(x_train,y_train)

print("Train Accuracy :",LR_score_train)

LR_score_test = model_LR.score(x_test,y_test)

print("Test Accuracy :",LR_score_test)

predictions_LR = model_LR.predict(x_test)

print('MAE:',metrics.mean_absolute_error(y_test,predictions_LR))

print('MSE:',metrics.mean_squared_error(y_test,predictions_LR))

LR_RMSE = np.sqrt(metrics.mean_squared_error(y_test,predictions_LR))

print('RMSE:',LR_RMSE)
# Out:
# using linear regression algorithm
# Train Accuracy : 0.2951381419161917
# Test Accuracy : 0.32230203252064205
# MAE: 0.3193161056243205
# MSE: 0.14370648838141725
# RMSE: 0.37908638643641274

# %%
print('using decision tree algorithm')
model_DT = tree.DecisionTreeRegressor(max_depth=3)

model_DT.fit(x_train,y_train)

DT_score_train = model_DT.score(x_train,y_train)

print("Train Accuracy :",DT_score_train)

DT_score_test = model_DT.score(x_test,y_test)

print("Test Accuracy :",DT_score_test)

predictions_DT = model_DT.predict(x_test)

print('MAE:',metrics.mean_absolute_error(y_test,predictions_DT))

print('MSE:',metrics.mean_squared_error(y_test,predictions_DT))

DT_RMSE = np.sqrt(metrics.mean_squared_error(y_test,predictions_DT))

print('RMSE:',DT_RMSE)
# Out:
# using decision tree algorithm
# Train Accuracy : 0.3405365947022857
# Test Accuracy : 0.2660784477956806
# MAE: 0.2920743067073311
# MSE: 0.15562875215194477
# RMSE: 0.39449810158218096
